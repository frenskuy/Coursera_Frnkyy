# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 241.0276 - y1_output_loss: 111.4245 - y2_output_loss: 127.4460 - y1_output_root_mean_squared_error: 10.6058 - y2_output_root_mean_squared_error: 11.3377 - val_loss: 33.9459 - val_y1_output_loss: 10.5689 - val_y2_output_loss: 22.4954 - val_y1_output_root_mean_squared_error: 3.3098 - val_y2_output_root_mean_squared_error: 4.7949
# Epoch 2/500
# 614/614 [==============================] - 0s 157us/sample - loss: 34.9980 - y1_output_loss: 13.4945 - y2_output_loss: 21.6895 - y1_output_root_mean_squared_error: 3.6410 - y2_output_root_mean_squared_error: 4.6627 - val_loss: 20.4417 - val_y1_output_loss: 8.8129 - val_y2_output_loss: 11.0779 - val_y1_output_root_mean_squared_error: 2.9976 - val_y2_output_root_mean_squared_error: 3.3847
# Epoch 3/500
# 614/614 [==============================] - 0s 152us/sample - loss: 27.2538 - y1_output_loss: 10.4656 - y2_output_loss: 16.6598 - y1_output_root_mean_squared_error: 3.2438 - y2_output_root_mean_squared_error: 4.0904 - val_loss: 23.7445 - val_y1_output_loss: 9.3470 - val_y2_output_loss: 13.6541 - val_y1_output_root_mean_squared_error: 3.1015 - val_y2_output_root_mean_squared_error: 3.7583
# Epoch 4/500
# 614/614 [==============================] - 0s 155us/sample - loss: 23.6288 - y1_output_loss: 9.7909 - y2_output_loss: 13.8846 - y1_output_root_mean_squared_error: 3.1179 - y2_output_root_mean_squared_error: 3.7292 - val_loss: 31.1842 - val_y1_output_loss: 11.7701 - val_y2_output_loss: 18.3850 - val_y1_output_root_mean_squared_error: 3.4901 - val_y2_output_root_mean_squared_error: 4.3593
# Epoch 5/500
# 614/614 [==============================] - 0s 148us/sample - loss: 24.7986 - y1_output_loss: 9.5686 - y2_output_loss: 15.0565 - y1_output_root_mean_squared_error: 3.1061 - y2_output_root_mean_squared_error: 3.8924 - val_loss: 19.6812 - val_y1_output_loss: 8.4665 - val_y2_output_loss: 10.8669 - val_y1_output_root_mean_squared_error: 2.9138 - val_y2_output_root_mean_squared_error: 3.3453
# Epoch 6/500
# 614/614 [==============================] - 0s 143us/sample - loss: 22.3842 - y1_output_loss: 9.4513 - y2_output_loss: 12.9465 - y1_output_root_mean_squared_error: 3.0639 - y2_output_root_mean_squared_error: 3.6051 - val_loss: 25.4057 - val_y1_output_loss: 10.2343 - val_y2_output_loss: 14.7848 - val_y1_output_root_mean_squared_error: 3.1873 - val_y2_output_root_mean_squared_error: 3.9047
# Epoch 7/500
# 614/614 [==============================] - 0s 158us/sample - loss: 25.6221 - y1_output_loss: 9.4796 - y2_output_loss: 16.3709 - y1_output_root_mean_squared_error: 3.0692 - y2_output_root_mean_squared_error: 4.0252 - val_loss: 24.3574 - val_y1_output_loss: 10.3628 - val_y2_output_loss: 13.4888 - val_y1_output_root_mean_squared_error: 3.2271 - val_y2_output_root_mean_squared_error: 3.7340
# Epoch 8/500
# 614/614 [==============================] - 0s 153us/sample - loss: 20.8249 - y1_output_loss: 8.5419 - y2_output_loss: 12.1455 - y1_output_root_mean_squared_error: 2.9339 - y2_output_root_mean_squared_error: 3.4953 - val_loss: 17.4975 - val_y1_output_loss: 7.5649 - val_y2_output_loss: 9.8233 - val_y1_output_root_mean_squared_error: 2.7287 - val_y2_output_root_mean_squared_error: 3.1705
# Epoch 9/500
# 614/614 [==============================] - 0s 139us/sample - loss: 21.4902 - y1_output_loss: 8.5772 - y2_output_loss: 13.0270 - y1_output_root_mean_squared_error: 2.9224 - y2_output_root_mean_squared_error: 3.5986 - val_loss: 53.5486 - val_y1_output_loss: 12.8543 - val_y2_output_loss: 40.4649 - val_y1_output_root_mean_squared_error: 3.5617 - val_y2_output_root_mean_squared_error: 6.3924
# Epoch 10/500
# 614/614 [==============================] - 0s 151us/sample - loss: 22.2539 - y1_output_loss: 8.6031 - y2_output_loss: 13.7707 - y1_output_root_mean_squared_error: 2.9097 - y2_output_root_mean_squared_error: 3.7131 - val_loss: 23.3085 - val_y1_output_loss: 8.6973 - val_y2_output_loss: 13.8328 - val_y1_output_root_mean_squared_error: 2.9941 - val_y2_output_root_mean_squared_error: 3.7873
# Epoch 11/500
# 614/614 [==============================] - 0s 149us/sample - loss: 24.4975 - y1_output_loss: 9.2967 - y2_output_loss: 15.3550 - y1_output_root_mean_squared_error: 3.0378 - y2_output_root_mean_squared_error: 3.9076 - val_loss: 26.6258 - val_y1_output_loss: 7.3811 - val_y2_output_loss: 18.4618 - val_y1_output_root_mean_squared_error: 2.7434 - val_y2_output_root_mean_squared_error: 4.3703
# Epoch 12/500
# 614/614 [==============================] - 0s 143us/sample - loss: 21.9965 - y1_output_loss: 8.3247 - y2_output_loss: 13.7593 - y1_output_root_mean_squared_error: 2.8838 - y2_output_root_mean_squared_error: 3.6987 - val_loss: 17.2828 - val_y1_output_loss: 6.6394 - val_y2_output_loss: 10.5518 - val_y1_output_root_mean_squared_error: 2.5699 - val_y2_output_root_mean_squared_error: 3.2677
# Epoch 13/500
# 614/614 [==============================] - 0s 164us/sample - loss: 27.1717 - y1_output_loss: 9.4790 - y2_output_loss: 18.0487 - y1_output_root_mean_squared_error: 3.0444 - y2_output_root_mean_squared_error: 4.2312 - val_loss: 43.2285 - val_y1_output_loss: 11.9995 - val_y2_output_loss: 29.9153 - val_y1_output_root_mean_squared_error: 3.5275 - val_y2_output_root_mean_squared_error: 5.5484
# Epoch 14/500
# 614/614 [==============================] - 0s 154us/sample - loss: 19.2557 - y1_output_loss: 7.7464 - y2_output_loss: 11.5457 - y1_output_root_mean_squared_error: 2.7813 - y2_output_root_mean_squared_error: 3.3941 - val_loss: 17.7321 - val_y1_output_loss: 6.8607 - val_y2_output_loss: 10.6888 - val_y1_output_root_mean_squared_error: 2.6084 - val_y2_output_root_mean_squared_error: 3.3058
# Epoch 15/500
# 614/614 [==============================] - 0s 141us/sample - loss: 19.1067 - y1_output_loss: 7.6438 - y2_output_loss: 11.3601 - y1_output_root_mean_squared_error: 2.7728 - y2_output_root_mean_squared_error: 3.3791 - val_loss: 14.8375 - val_y1_output_loss: 5.7975 - val_y2_output_loss: 8.7514 - val_y1_output_root_mean_squared_error: 2.4048 - val_y2_output_root_mean_squared_error: 3.0091
# Epoch 16/500
# 614/614 [==============================] - 0s 154us/sample - loss: 21.2791 - y1_output_loss: 7.6358 - y2_output_loss: 13.5233 - y1_output_root_mean_squared_error: 2.7724 - y2_output_root_mean_squared_error: 3.6869 - val_loss: 16.3495 - val_y1_output_loss: 6.3702 - val_y2_output_loss: 9.6468 - val_y1_output_root_mean_squared_error: 2.5222 - val_y2_output_root_mean_squared_error: 3.1603
# Epoch 17/500
# 614/614 [==============================] - 0s 157us/sample - loss: 17.3011 - y1_output_loss: 6.9546 - y2_output_loss: 10.2239 - y1_output_root_mean_squared_error: 2.6480 - y2_output_root_mean_squared_error: 3.2077 - val_loss: 13.9849 - val_y1_output_loss: 5.8986 - val_y2_output_loss: 7.8836 - val_y1_output_root_mean_squared_error: 2.4203 - val_y2_output_root_mean_squared_error: 2.8508
# Epoch 18/500
# 614/614 [==============================] - 0s 143us/sample - loss: 16.0846 - y1_output_loss: 6.4501 - y2_output_loss: 9.7713 - y1_output_root_mean_squared_error: 2.5380 - y2_output_root_mean_squared_error: 3.1054 - val_loss: 19.6963 - val_y1_output_loss: 7.3926 - val_y2_output_loss: 11.8740 - val_y1_output_root_mean_squared_error: 2.7194 - val_y2_output_root_mean_squared_error: 3.5073
# Epoch 19/500
# 614/614 [==============================] - 0s 169us/sample - loss: 17.6656 - y1_output_loss: 6.6441 - y2_output_loss: 10.9239 - y1_output_root_mean_squared_error: 2.5878 - y2_output_root_mean_squared_error: 3.3119 - val_loss: 14.2536 - val_y1_output_loss: 5.9322 - val_y2_output_loss: 8.4296 - val_y1_output_root_mean_squared_error: 2.3957 - val_y2_output_root_mean_squared_error: 2.9179
# Epoch 20/500
# 614/614 [==============================] - 0s 149us/sample - loss: 16.1295 - y1_output_loss: 6.2402 - y2_output_loss: 9.7945 - y1_output_root_mean_squared_error: 2.4998 - y2_output_root_mean_squared_error: 3.1433 - val_loss: 12.8707 - val_y1_output_loss: 5.6080 - val_y2_output_loss: 7.2113 - val_y1_output_root_mean_squared_error: 2.3398 - val_y2_output_root_mean_squared_error: 2.7196
# Epoch 21/500
# 614/614 [==============================] - 0s 141us/sample - loss: 15.1208 - y1_output_loss: 5.6800 - y2_output_loss: 9.3234 - y1_output_root_mean_squared_error: 2.3901 - y2_output_root_mean_squared_error: 3.0673 - val_loss: 12.0505 - val_y1_output_loss: 5.1654 - val_y2_output_loss: 6.9719 - val_y1_output_root_mean_squared_error: 2.2291 - val_y2_output_root_mean_squared_error: 2.6611
# Epoch 22/500
# 614/614 [==============================] - 0s 161us/sample - loss: 14.2225 - y1_output_loss: 5.4353 - y2_output_loss: 8.6963 - y1_output_root_mean_squared_error: 2.3346 - y2_output_root_mean_squared_error: 2.9618 - val_loss: 11.7350 - val_y1_output_loss: 5.2079 - val_y2_output_loss: 6.6156 - val_y1_output_root_mean_squared_error: 2.2251 - val_y2_output_root_mean_squared_error: 2.6046
# Epoch 23/500
# 614/614 [==============================] - 0s 153us/sample - loss: 15.9263 - y1_output_loss: 5.6719 - y2_output_loss: 10.2227 - y1_output_root_mean_squared_error: 2.3727 - y2_output_root_mean_squared_error: 3.2088 - val_loss: 10.7182 - val_y1_output_loss: 4.5502 - val_y2_output_loss: 6.1094 - val_y1_output_root_mean_squared_error: 2.1047 - val_y2_output_root_mean_squared_error: 2.5077
# Epoch 24/500
# 614/614 [==============================] - 0s 144us/sample - loss: 14.2067 - y1_output_loss: 5.1116 - y2_output_loss: 9.2762 - y1_output_root_mean_squared_error: 2.2493 - y2_output_root_mean_squared_error: 3.0244 - val_loss: 18.3468 - val_y1_output_loss: 5.3404 - val_y2_output_loss: 13.0772 - val_y1_output_root_mean_squared_error: 2.2774 - val_y2_output_root_mean_squared_error: 3.6277
# Epoch 25/500
# 614/614 [==============================] - 0s 176us/sample - loss: 12.4412 - y1_output_loss: 4.4865 - y2_output_loss: 7.8691 - y1_output_root_mean_squared_error: 2.1258 - y2_output_root_mean_squared_error: 2.8147 - val_loss: 15.9051 - val_y1_output_loss: 5.2215 - val_y2_output_loss: 10.1858 - val_y1_output_root_mean_squared_error: 2.3124 - val_y2_output_root_mean_squared_error: 3.2493
# Epoch 26/500
# 614/614 [==============================] - 0s 161us/sample - loss: 13.0308 - y1_output_loss: 4.2739 - y2_output_loss: 8.7022 - y1_output_root_mean_squared_error: 2.0659 - y2_output_root_mean_squared_error: 2.9602 - val_loss: 10.6287 - val_y1_output_loss: 3.9408 - val_y2_output_loss: 6.5072 - val_y1_output_root_mean_squared_error: 1.9716 - val_y2_output_root_mean_squared_error: 2.5965
# Epoch 27/500
# 614/614 [==============================] - 0s 170us/sample - loss: 11.2053 - y1_output_loss: 4.1450 - y2_output_loss: 7.0423 - y1_output_root_mean_squared_error: 2.0406 - y2_output_root_mean_squared_error: 2.6535 - val_loss: 8.9050 - val_y1_output_loss: 3.4999 - val_y2_output_loss: 5.3119 - val_y1_output_root_mean_squared_error: 1.8599 - val_y2_output_root_mean_squared_error: 2.3336
# Epoch 28/500
# 614/614 [==============================] - 0s 160us/sample - loss: 9.5692 - y1_output_loss: 3.6065 - y2_output_loss: 5.9628 - y1_output_root_mean_squared_error: 1.9029 - y2_output_root_mean_squared_error: 2.4389 - val_loss: 8.6354 - val_y1_output_loss: 3.5306 - val_y2_output_loss: 5.0236 - val_y1_output_root_mean_squared_error: 1.8628 - val_y2_output_root_mean_squared_error: 2.2727
# Epoch 29/500
# 614/614 [==============================] - 0s 156us/sample - loss: 9.1580 - y1_output_loss: 3.4450 - y2_output_loss: 5.9795 - y1_output_root_mean_squared_error: 1.8163 - y2_output_root_mean_squared_error: 2.4205 - val_loss: 25.3938 - val_y1_output_loss: 6.7024 - val_y2_output_loss: 17.9614 - val_y1_output_root_mean_squared_error: 2.6302 - val_y2_output_root_mean_squared_error: 4.2983
# Epoch 30/500
# 614/614 [==============================] - 0s 155us/sample - loss: 8.6853 - y1_output_loss: 2.9520 - y2_output_loss: 5.6691 - y1_output_root_mean_squared_error: 1.7255 - y2_output_root_mean_squared_error: 2.3891 - val_loss: 8.9154 - val_y1_output_loss: 3.4683 - val_y2_output_loss: 5.3209 - val_y1_output_root_mean_squared_error: 1.8505 - val_y2_output_root_mean_squared_error: 2.3433
# Epoch 31/500
# 614/614 [==============================] - 0s 173us/sample - loss: 13.0216 - y1_output_loss: 4.0871 - y2_output_loss: 8.8234 - y1_output_root_mean_squared_error: 2.0294 - y2_output_root_mean_squared_error: 2.9838 - val_loss: 7.9579 - val_y1_output_loss: 2.9734 - val_y2_output_loss: 4.8914 - val_y1_output_root_mean_squared_error: 1.7130 - val_y2_output_root_mean_squared_error: 2.2413
# Epoch 32/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.6734 - y1_output_loss: 3.6455 - y2_output_loss: 7.1688 - y1_output_root_mean_squared_error: 1.9076 - y2_output_root_mean_squared_error: 2.6522 - val_loss: 23.2691 - val_y1_output_loss: 5.8238 - val_y2_output_loss: 17.2068 - val_y1_output_root_mean_squared_error: 2.3999 - val_y2_output_root_mean_squared_error: 4.1844
# Epoch 33/500
# 614/614 [==============================] - 0s 155us/sample - loss: 9.7473 - y1_output_loss: 3.1040 - y2_output_loss: 6.8114 - y1_output_root_mean_squared_error: 1.7502 - y2_output_root_mean_squared_error: 2.5853 - val_loss: 40.0488 - val_y1_output_loss: 13.8604 - val_y2_output_loss: 25.2499 - val_y1_output_root_mean_squared_error: 3.7543 - val_y2_output_root_mean_squared_error: 5.0945
# Epoch 34/500
# 614/614 [==============================] - 0s 148us/sample - loss: 10.6239 - y1_output_loss: 3.3097 - y2_output_loss: 7.2762 - y1_output_root_mean_squared_error: 1.8274 - y2_output_root_mean_squared_error: 2.6990 - val_loss: 10.6861 - val_y1_output_loss: 3.6378 - val_y2_output_loss: 7.0405 - val_y1_output_root_mean_squared_error: 1.8807 - val_y2_output_root_mean_squared_error: 2.6738
# Epoch 35/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.9650 - y1_output_loss: 2.5993 - y2_output_loss: 6.4019 - y1_output_root_mean_squared_error: 1.6143 - y2_output_root_mean_squared_error: 2.5217 - val_loss: 23.8832 - val_y1_output_loss: 7.1572 - val_y2_output_loss: 15.9443 - val_y1_output_root_mean_squared_error: 2.7257 - val_y2_output_root_mean_squared_error: 4.0563
# Epoch 36/500
# 614/614 [==============================] - 0s 138us/sample - loss: 7.9569 - y1_output_loss: 2.5038 - y2_output_loss: 5.4172 - y1_output_root_mean_squared_error: 1.5888 - y2_output_root_mean_squared_error: 2.3308 - val_loss: 7.6798 - val_y1_output_loss: 2.3915 - val_y2_output_loss: 5.2838 - val_y1_output_root_mean_squared_error: 1.5245 - val_y2_output_root_mean_squared_error: 2.3143
# Epoch 37/500
# 614/614 [==============================] - 0s 165us/sample - loss: 9.7977 - y1_output_loss: 3.0164 - y2_output_loss: 6.7290 - y1_output_root_mean_squared_error: 1.7399 - y2_output_root_mean_squared_error: 2.6020 - val_loss: 12.2562 - val_y1_output_loss: 3.1402 - val_y2_output_loss: 9.0124 - val_y1_output_root_mean_squared_error: 1.7587 - val_y2_output_root_mean_squared_error: 3.0271
# Epoch 38/500
# 614/614 [==============================] - 0s 137us/sample - loss: 7.6585 - y1_output_loss: 2.1879 - y2_output_loss: 5.6237 - y1_output_root_mean_squared_error: 1.4786 - y2_output_root_mean_squared_error: 2.3393 - val_loss: 8.2296 - val_y1_output_loss: 2.6020 - val_y2_output_loss: 5.6624 - val_y1_output_root_mean_squared_error: 1.5831 - val_y2_output_root_mean_squared_error: 2.3923
# Epoch 39/500
# 614/614 [==============================] - 0s 154us/sample - loss: 7.5810 - y1_output_loss: 2.4032 - y2_output_loss: 5.1489 - y1_output_root_mean_squared_error: 1.5534 - y2_output_root_mean_squared_error: 2.2733 - val_loss: 10.3766 - val_y1_output_loss: 2.7970 - val_y2_output_loss: 7.2920 - val_y1_output_root_mean_squared_error: 1.6847 - val_y2_output_root_mean_squared_error: 2.7456
# Epoch 40/500
# 614/614 [==============================] - 0s 158us/sample - loss: 8.8169 - y1_output_loss: 2.6031 - y2_output_loss: 6.2161 - y1_output_root_mean_squared_error: 1.6137 - y2_output_root_mean_squared_error: 2.4926 - val_loss: 19.7089 - val_y1_output_loss: 3.7752 - val_y2_output_loss: 15.3841 - val_y1_output_root_mean_squared_error: 1.9740 - val_y2_output_root_mean_squared_error: 3.9765
# Epoch 41/500
# 614/614 [==============================] - 0s 138us/sample - loss: 11.0272 - y1_output_loss: 3.1136 - y2_output_loss: 7.9301 - y1_output_root_mean_squared_error: 1.7569 - y2_output_root_mean_squared_error: 2.8179 - val_loss: 8.8903 - val_y1_output_loss: 2.3374 - val_y2_output_loss: 6.2893 - val_y1_output_root_mean_squared_error: 1.5432 - val_y2_output_root_mean_squared_error: 2.5513
# Epoch 42/500
# 614/614 [==============================] - 0s 143us/sample - loss: 8.2263 - y1_output_loss: 2.4874 - y2_output_loss: 5.7670 - y1_output_root_mean_squared_error: 1.5775 - y2_output_root_mean_squared_error: 2.3953 - val_loss: 26.1703 - val_y1_output_loss: 6.7739 - val_y2_output_loss: 18.6110 - val_y1_output_root_mean_squared_error: 2.6524 - val_y2_output_root_mean_squared_error: 4.3743
# Epoch 43/500
# 614/614 [==============================] - 0s 176us/sample - loss: 7.2910 - y1_output_loss: 2.2021 - y2_output_loss: 5.0262 - y1_output_root_mean_squared_error: 1.4908 - y2_output_root_mean_squared_error: 2.2513 - val_loss: 13.0811 - val_y1_output_loss: 4.1097 - val_y2_output_loss: 8.5501 - val_y1_output_root_mean_squared_error: 2.0653 - val_y2_output_root_mean_squared_error: 2.9691
# Epoch 44/500
# 614/614 [==============================] - 0s 142us/sample - loss: 6.0893 - y1_output_loss: 1.8031 - y2_output_loss: 4.2769 - y1_output_root_mean_squared_error: 1.3429 - y2_output_root_mean_squared_error: 2.0703 - val_loss: 8.0658 - val_y1_output_loss: 2.6616 - val_y2_output_loss: 5.1616 - val_y1_output_root_mean_squared_error: 1.6492 - val_y2_output_root_mean_squared_error: 2.3121
# Epoch 45/500
# 614/614 [==============================] - 0s 156us/sample - loss: 6.6437 - y1_output_loss: 2.0036 - y2_output_loss: 4.6832 - y1_output_root_mean_squared_error: 1.4015 - y2_output_root_mean_squared_error: 2.1632 - val_loss: 26.2465 - val_y1_output_loss: 8.3270 - val_y2_output_loss: 17.1113 - val_y1_output_root_mean_squared_error: 2.9393 - val_y2_output_root_mean_squared_error: 4.1961
# Epoch 46/500
# 614/614 [==============================] - 0s 149us/sample - loss: 6.8012 - y1_output_loss: 1.9134 - y2_output_loss: 4.8718 - y1_output_root_mean_squared_error: 1.3809 - y2_output_root_mean_squared_error: 2.2123 - val_loss: 5.2955 - val_y1_output_loss: 1.8522 - val_y2_output_loss: 3.3125 - val_y1_output_root_mean_squared_error: 1.3636 - val_y2_output_root_mean_squared_error: 1.8536
# Epoch 47/500
# 614/614 [==============================] - 0s 142us/sample - loss: 7.2088 - y1_output_loss: 1.9089 - y2_output_loss: 5.2323 - y1_output_root_mean_squared_error: 1.3882 - y2_output_root_mean_squared_error: 2.2982 - val_loss: 6.1466 - val_y1_output_loss: 1.8751 - val_y2_output_loss: 4.0876 - val_y1_output_root_mean_squared_error: 1.3828 - val_y2_output_root_mean_squared_error: 2.0578
# Epoch 48/500
# 614/614 [==============================] - 0s 160us/sample - loss: 7.5551 - y1_output_loss: 2.2499 - y2_output_loss: 5.2686 - y1_output_root_mean_squared_error: 1.5056 - y2_output_root_mean_squared_error: 2.2996 - val_loss: 4.9193 - val_y1_output_loss: 1.7006 - val_y2_output_loss: 3.1069 - val_y1_output_root_mean_squared_error: 1.3078 - val_y2_output_root_mean_squared_error: 1.7914
# Epoch 49/500
# 614/614 [==============================] - 0s 166us/sample - loss: 7.5851 - y1_output_loss: 2.3440 - y2_output_loss: 5.3671 - y1_output_root_mean_squared_error: 1.5306 - y2_output_root_mean_squared_error: 2.2896 - val_loss: 20.5368 - val_y1_output_loss: 5.5339 - val_y2_output_loss: 14.7283 - val_y1_output_root_mean_squared_error: 2.3502 - val_y2_output_root_mean_squared_error: 3.8747
# Epoch 50/500
# 614/614 [==============================] - 0s 147us/sample - loss: 9.2705 - y1_output_loss: 2.5897 - y2_output_loss: 6.6087 - y1_output_root_mean_squared_error: 1.6134 - y2_output_root_mean_squared_error: 2.5821 - val_loss: 7.9853 - val_y1_output_loss: 2.9045 - val_y2_output_loss: 4.9149 - val_y1_output_root_mean_squared_error: 1.7081 - val_y2_output_root_mean_squared_error: 2.2512
# Epoch 51/500
# 614/614 [==============================] - 0s 178us/sample - loss: 5.9849 - y1_output_loss: 1.6910 - y2_output_loss: 4.2861 - y1_output_root_mean_squared_error: 1.2981 - y2_output_root_mean_squared_error: 2.0736 - val_loss: 10.3879 - val_y1_output_loss: 3.5392 - val_y2_output_loss: 6.4975 - val_y1_output_root_mean_squared_error: 1.9122 - val_y2_output_root_mean_squared_error: 2.5945
# Epoch 52/500
# 614/614 [==============================] - 0s 147us/sample - loss: 5.1497 - y1_output_loss: 1.4765 - y2_output_loss: 3.7668 - y1_output_root_mean_squared_error: 1.2152 - y2_output_root_mean_squared_error: 1.9165 - val_loss: 16.6984 - val_y1_output_loss: 3.7096 - val_y2_output_loss: 12.4982 - val_y1_output_root_mean_squared_error: 1.9619 - val_y2_output_root_mean_squared_error: 3.5846
# Epoch 53/500
# 614/614 [==============================] - 0s 141us/sample - loss: 6.5197 - y1_output_loss: 1.7881 - y2_output_loss: 4.7680 - y1_output_root_mean_squared_error: 1.3372 - y2_output_root_mean_squared_error: 2.1752 - val_loss: 5.9670 - val_y1_output_loss: 2.0820 - val_y2_output_loss: 3.7870 - val_y1_output_root_mean_squared_error: 1.4383 - val_y2_output_root_mean_squared_error: 1.9744
# Epoch 54/500
# 614/614 [==============================] - 0s 166us/sample - loss: 6.8877 - y1_output_loss: 1.8796 - y2_output_loss: 4.9679 - y1_output_root_mean_squared_error: 1.3757 - y2_output_root_mean_squared_error: 2.2350 - val_loss: 6.1859 - val_y1_output_loss: 1.8462 - val_y2_output_loss: 4.1660 - val_y1_output_root_mean_squared_error: 1.3723 - val_y2_output_root_mean_squared_error: 2.0743
# Epoch 55/500
# 614/614 [==============================] - 0s 145us/sample - loss: 5.3136 - y1_output_loss: 1.4603 - y2_output_loss: 3.8966 - y1_output_root_mean_squared_error: 1.2041 - y2_output_root_mean_squared_error: 1.9657 - val_loss: 10.2248 - val_y1_output_loss: 2.6901 - val_y2_output_loss: 7.2467 - val_y1_output_root_mean_squared_error: 1.6520 - val_y2_output_root_mean_squared_error: 2.7378
# Epoch 56/500
# 614/614 [==============================] - 0s 153us/sample - loss: 5.4223 - y1_output_loss: 1.4774 - y2_output_loss: 3.9477 - y1_output_root_mean_squared_error: 1.2142 - y2_output_root_mean_squared_error: 1.9869 - val_loss: 11.6185 - val_y1_output_loss: 3.6555 - val_y2_output_loss: 7.6011 - val_y1_output_root_mean_squared_error: 1.9410 - val_y2_output_root_mean_squared_error: 2.8020
# Epoch 57/500
# 614/614 [==============================] - 0s 155us/sample - loss: 10.9009 - y1_output_loss: 3.1564 - y2_output_loss: 7.6651 - y1_output_root_mean_squared_error: 1.7794 - y2_output_root_mean_squared_error: 2.7812 - val_loss: 5.5846 - val_y1_output_loss: 1.7803 - val_y2_output_loss: 3.7118 - val_y1_output_root_mean_squared_error: 1.3274 - val_y2_output_root_mean_squared_error: 1.9552
# Epoch 58/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.2762 - y1_output_loss: 1.4779 - y2_output_loss: 3.8087 - y1_output_root_mean_squared_error: 1.2157 - y2_output_root_mean_squared_error: 1.9489 - val_loss: 5.2389 - val_y1_output_loss: 1.4784 - val_y2_output_loss: 3.6085 - val_y1_output_root_mean_squared_error: 1.2279 - val_y2_output_root_mean_squared_error: 1.9316
# Epoch 59/500
# 614/614 [==============================] - 0s 144us/sample - loss: 8.3312 - y1_output_loss: 2.2149 - y2_output_loss: 6.0695 - y1_output_root_mean_squared_error: 1.4909 - y2_output_root_mean_squared_error: 2.4715 - val_loss: 4.7298 - val_y1_output_loss: 1.8890 - val_y2_output_loss: 2.7300 - val_y1_output_root_mean_squared_error: 1.3801 - val_y2_output_root_mean_squared_error: 1.6808
# Epoch 60/500
# 614/614 [==============================] - 0s 174us/sample - loss: 6.2707 - y1_output_loss: 1.5600 - y2_output_loss: 4.6770 - y1_output_root_mean_squared_error: 1.2489 - y2_output_root_mean_squared_error: 2.1704 - val_loss: 9.8333 - val_y1_output_loss: 2.0250 - val_y2_output_loss: 7.5373 - val_y1_output_root_mean_squared_error: 1.4450 - val_y2_output_root_mean_squared_error: 2.7830
# Epoch 61/500
# 614/614 [==============================] - 0s 147us/sample - loss: 6.4708 - y1_output_loss: 1.7870 - y2_output_loss: 4.6775 - y1_output_root_mean_squared_error: 1.3383 - y2_output_root_mean_squared_error: 2.1632 - val_loss: 6.2965 - val_y1_output_loss: 1.3500 - val_y2_output_loss: 4.7766 - val_y1_output_root_mean_squared_error: 1.1738 - val_y2_output_root_mean_squared_error: 2.2178
# Epoch 62/500
# 614/614 [==============================] - 0s 154us/sample - loss: 5.3000 - y1_output_loss: 1.5294 - y2_output_loss: 3.7296 - y1_output_root_mean_squared_error: 1.2414 - y2_output_root_mean_squared_error: 1.9388 - val_loss: 6.2287 - val_y1_output_loss: 1.8027 - val_y2_output_loss: 4.3216 - val_y1_output_root_mean_squared_error: 1.3431 - val_y2_output_root_mean_squared_error: 2.1035
# Epoch 63/500
# 614/614 [==============================] - 0s 155us/sample - loss: 4.3172 - y1_output_loss: 1.1927 - y2_output_loss: 3.2942 - y1_output_root_mean_squared_error: 1.0690 - y2_output_root_mean_squared_error: 1.7817 - val_loss: 31.1573 - val_y1_output_loss: 9.2954 - val_y2_output_loss: 21.0135 - val_y1_output_root_mean_squared_error: 3.1019 - val_y2_output_root_mean_squared_error: 4.6407
# Epoch 64/500
# 614/614 [==============================] - 0s 142us/sample - loss: 9.2893 - y1_output_loss: 2.5624 - y2_output_loss: 6.6393 - y1_output_root_mean_squared_error: 1.6082 - y2_output_root_mean_squared_error: 2.5890 - val_loss: 3.6680 - val_y1_output_loss: 1.1526 - val_y2_output_loss: 2.4016 - val_y1_output_root_mean_squared_error: 1.0900 - val_y2_output_root_mean_squared_error: 1.5748
# Epoch 65/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.6654 - y1_output_loss: 1.1248 - y2_output_loss: 3.5354 - y1_output_root_mean_squared_error: 1.0641 - y2_output_root_mean_squared_error: 1.8797 - val_loss: 8.9955 - val_y1_output_loss: 3.0546 - val_y2_output_loss: 5.7431 - val_y1_output_root_mean_squared_error: 1.7593 - val_y2_output_root_mean_squared_error: 2.4290
# Epoch 66/500
# 614/614 [==============================] - 0s 167us/sample - loss: 4.8411 - y1_output_loss: 1.1783 - y2_output_loss: 3.6266 - y1_output_root_mean_squared_error: 1.0906 - y2_output_root_mean_squared_error: 1.9109 - val_loss: 3.4489 - val_y1_output_loss: 1.0099 - val_y2_output_loss: 2.3360 - val_y1_output_root_mean_squared_error: 1.0194 - val_y2_output_root_mean_squared_error: 1.5523
# Epoch 67/500
# 614/614 [==============================] - 0s 139us/sample - loss: 4.9499 - y1_output_loss: 1.4578 - y2_output_loss: 3.6215 - y1_output_root_mean_squared_error: 1.1817 - y2_output_root_mean_squared_error: 1.8851 - val_loss: 27.8846 - val_y1_output_loss: 7.6937 - val_y2_output_loss: 19.3989 - val_y1_output_root_mean_squared_error: 2.8118 - val_y2_output_root_mean_squared_error: 4.4697
# Epoch 68/500
# 614/614 [==============================] - 0s 158us/sample - loss: 9.5561 - y1_output_loss: 2.9578 - y2_output_loss: 6.6674 - y1_output_root_mean_squared_error: 1.7192 - y2_output_root_mean_squared_error: 2.5692 - val_loss: 7.9112 - val_y1_output_loss: 3.0150 - val_y2_output_loss: 4.7025 - val_y1_output_root_mean_squared_error: 1.7543 - val_y2_output_root_mean_squared_error: 2.1985
# Epoch 69/500
# 614/614 [==============================] - 0s 171us/sample - loss: 4.9418 - y1_output_loss: 1.4021 - y2_output_loss: 3.5152 - y1_output_root_mean_squared_error: 1.1821 - y2_output_root_mean_squared_error: 1.8827 - val_loss: 4.7781 - val_y1_output_loss: 1.8550 - val_y2_output_loss: 2.7551 - val_y1_output_root_mean_squared_error: 1.3852 - val_y2_output_root_mean_squared_error: 1.6910
# Epoch 70/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.0184 - y1_output_loss: 1.2717 - y2_output_loss: 3.7575 - y1_output_root_mean_squared_error: 1.1306 - y2_output_root_mean_squared_error: 1.9339 - val_loss: 4.5653 - val_y1_output_loss: 1.2118 - val_y2_output_loss: 3.2181 - val_y1_output_root_mean_squared_error: 1.1195 - val_y2_output_root_mean_squared_error: 1.8199
# Epoch 71/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.0183 - y1_output_loss: 0.9428 - y2_output_loss: 3.0413 - y1_output_root_mean_squared_error: 0.9746 - y2_output_root_mean_squared_error: 1.7517 - val_loss: 3.2712 - val_y1_output_loss: 0.8515 - val_y2_output_loss: 2.3230 - val_y1_output_root_mean_squared_error: 0.9339 - val_y2_output_root_mean_squared_error: 1.5489
# Epoch 72/500
# 614/614 [==============================] - 0s 170us/sample - loss: 6.3319 - y1_output_loss: 1.8792 - y2_output_loss: 4.4491 - y1_output_root_mean_squared_error: 1.3721 - y2_output_root_mean_squared_error: 2.1093 - val_loss: 6.9216 - val_y1_output_loss: 1.1795 - val_y2_output_loss: 5.6209 - val_y1_output_root_mean_squared_error: 1.1064 - val_y2_output_root_mean_squared_error: 2.3870
# Epoch 73/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.8017 - y1_output_loss: 0.8621 - y2_output_loss: 2.9494 - y1_output_root_mean_squared_error: 0.9311 - y2_output_root_mean_squared_error: 1.7131 - val_loss: 3.0040 - val_y1_output_loss: 0.9040 - val_y2_output_loss: 2.0069 - val_y1_output_root_mean_squared_error: 0.9675 - val_y2_output_root_mean_squared_error: 1.4380
# Epoch 74/500
# 614/614 [==============================] - 0s 156us/sample - loss: 3.7573 - y1_output_loss: 0.8412 - y2_output_loss: 2.9050 - y1_output_root_mean_squared_error: 0.9173 - y2_output_root_mean_squared_error: 1.7076 - val_loss: 7.9749 - val_y1_output_loss: 1.9591 - val_y2_output_loss: 5.7864 - val_y1_output_root_mean_squared_error: 1.4258 - val_y2_output_root_mean_squared_error: 2.4376
# Epoch 75/500
# 614/614 [==============================] - 0s 148us/sample - loss: 5.1897 - y1_output_loss: 1.3960 - y2_output_loss: 3.7961 - y1_output_root_mean_squared_error: 1.1731 - y2_output_root_mean_squared_error: 1.9528 - val_loss: 5.4203 - val_y1_output_loss: 1.7592 - val_y2_output_loss: 3.4921 - val_y1_output_root_mean_squared_error: 1.3461 - val_y2_output_root_mean_squared_error: 1.8995
# Epoch 76/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.4889 - y1_output_loss: 0.8344 - y2_output_loss: 2.6580 - y1_output_root_mean_squared_error: 0.9096 - y2_output_root_mean_squared_error: 1.6314 - val_loss: 3.4858 - val_y1_output_loss: 0.8114 - val_y2_output_loss: 2.5814 - val_y1_output_root_mean_squared_error: 0.9150 - val_y2_output_root_mean_squared_error: 1.6274
# Epoch 77/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.9021 - y1_output_loss: 0.6895 - y2_output_loss: 2.1951 - y1_output_root_mean_squared_error: 0.8339 - y2_output_root_mean_squared_error: 1.4855 - val_loss: 4.7727 - val_y1_output_loss: 0.9954 - val_y2_output_loss: 3.6521 - val_y1_output_root_mean_squared_error: 1.0085 - val_y2_output_root_mean_squared_error: 1.9380
# Epoch 78/500
# 614/614 [==============================] - 0s 165us/sample - loss: 3.9163 - y1_output_loss: 0.8469 - y2_output_loss: 3.0340 - y1_output_root_mean_squared_error: 0.9239 - y2_output_root_mean_squared_error: 1.7501 - val_loss: 3.3456 - val_y1_output_loss: 0.8898 - val_y2_output_loss: 2.3428 - val_y1_output_root_mean_squared_error: 0.9608 - val_y2_output_root_mean_squared_error: 1.5564
# Epoch 79/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3615 - y1_output_loss: 0.8729 - y2_output_loss: 2.4659 - y1_output_root_mean_squared_error: 0.9364 - y2_output_root_mean_squared_error: 1.5763 - val_loss: 3.7758 - val_y1_output_loss: 0.7540 - val_y2_output_loss: 2.9144 - val_y1_output_root_mean_squared_error: 0.8835 - val_y2_output_root_mean_squared_error: 1.7307
# Epoch 80/500
# 614/614 [==============================] - 0s 163us/sample - loss: 3.3617 - y1_output_loss: 0.8555 - y2_output_loss: 2.5100 - y1_output_root_mean_squared_error: 0.9220 - y2_output_root_mean_squared_error: 1.5848 - val_loss: 9.0557 - val_y1_output_loss: 1.6545 - val_y2_output_loss: 7.1814 - val_y1_output_root_mean_squared_error: 1.3089 - val_y2_output_root_mean_squared_error: 2.7097
# Epoch 81/500
# 614/614 [==============================] - 0s 158us/sample - loss: 3.8956 - y1_output_loss: 0.8630 - y2_output_loss: 3.0176 - y1_output_root_mean_squared_error: 0.9318 - y2_output_root_mean_squared_error: 1.7399 - val_loss: 6.5999 - val_y1_output_loss: 1.0334 - val_y2_output_loss: 5.4022 - val_y1_output_root_mean_squared_error: 1.0345 - val_y2_output_root_mean_squared_error: 2.3515
# Epoch 82/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3798 - y1_output_loss: 0.8306 - y2_output_loss: 2.5445 - y1_output_root_mean_squared_error: 0.9016 - y2_output_root_mean_squared_error: 1.6022 - val_loss: 3.9065 - val_y1_output_loss: 1.4739 - val_y2_output_loss: 2.3322 - val_y1_output_root_mean_squared_error: 1.2258 - val_y2_output_root_mean_squared_error: 1.5504
# Epoch 83/500
# 614/614 [==============================] - 0s 141us/sample - loss: 4.4657 - y1_output_loss: 1.1563 - y2_output_loss: 3.2824 - y1_output_root_mean_squared_error: 1.0765 - y2_output_root_mean_squared_error: 1.8184 - val_loss: 3.6815 - val_y1_output_loss: 1.3413 - val_y2_output_loss: 2.2113 - val_y1_output_root_mean_squared_error: 1.1782 - val_y2_output_root_mean_squared_error: 1.5144
# Epoch 84/500
# 614/614 [==============================] - 0s 171us/sample - loss: 5.0375 - y1_output_loss: 1.2881 - y2_output_loss: 3.7334 - y1_output_root_mean_squared_error: 1.1394 - y2_output_root_mean_squared_error: 1.9337 - val_loss: 3.0872 - val_y1_output_loss: 0.9228 - val_y2_output_loss: 2.0801 - val_y1_output_root_mean_squared_error: 0.9717 - val_y2_output_root_mean_squared_error: 1.4639
# Epoch 85/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.6975 - y1_output_loss: 0.8840 - y2_output_loss: 2.7890 - y1_output_root_mean_squared_error: 0.9413 - y2_output_root_mean_squared_error: 1.6767 - val_loss: 2.5791 - val_y1_output_loss: 0.6823 - val_y2_output_loss: 1.8054 - val_y1_output_root_mean_squared_error: 0.8415 - val_y2_output_root_mean_squared_error: 1.3679
# Epoch 86/500
# 614/614 [==============================] - 0s 157us/sample - loss: 3.4983 - y1_output_loss: 0.9381 - y2_output_loss: 2.5544 - y1_output_root_mean_squared_error: 0.9636 - y2_output_root_mean_squared_error: 1.6031 - val_loss: 2.6658 - val_y1_output_loss: 0.7403 - val_y2_output_loss: 1.8363 - val_y1_output_root_mean_squared_error: 0.8729 - val_y2_output_root_mean_squared_error: 1.3798
# Epoch 87/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.4732 - y1_output_loss: 0.8620 - y2_output_loss: 2.6070 - y1_output_root_mean_squared_error: 0.9306 - y2_output_root_mean_squared_error: 1.6147 - val_loss: 2.4831 - val_y1_output_loss: 0.5448 - val_y2_output_loss: 1.8626 - val_y1_output_root_mean_squared_error: 0.7496 - val_y2_output_root_mean_squared_error: 1.3861
# Epoch 88/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4222 - y1_output_loss: 0.6687 - y2_output_loss: 2.7390 - y1_output_root_mean_squared_error: 0.8168 - y2_output_root_mean_squared_error: 1.6598 - val_loss: 2.1482 - val_y1_output_loss: 0.5970 - val_y2_output_loss: 1.4825 - val_y1_output_root_mean_squared_error: 0.7853 - val_y2_output_root_mean_squared_error: 1.2375
# Epoch 89/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.0234 - y1_output_loss: 1.3744 - y2_output_loss: 3.6831 - y1_output_root_mean_squared_error: 1.1734 - y2_output_root_mean_squared_error: 1.9096 - val_loss: 5.9113 - val_y1_output_loss: 1.5115 - val_y2_output_loss: 4.3100 - val_y1_output_root_mean_squared_error: 1.2404 - val_y2_output_root_mean_squared_error: 2.0911
# Epoch 90/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.1240 - y1_output_loss: 0.7274 - y2_output_loss: 2.4232 - y1_output_root_mean_squared_error: 0.8550 - y2_output_root_mean_squared_error: 1.5469 - val_loss: 8.6727 - val_y1_output_loss: 2.3580 - val_y2_output_loss: 6.0630 - val_y1_output_root_mean_squared_error: 1.5598 - val_y2_output_root_mean_squared_error: 2.4979
# Epoch 91/500
# 614/614 [==============================] - 0s 141us/sample - loss: 3.4395 - y1_output_loss: 0.9980 - y2_output_loss: 2.4109 - y1_output_root_mean_squared_error: 1.0036 - y2_output_root_mean_squared_error: 1.5596 - val_loss: 3.1747 - val_y1_output_loss: 0.5994 - val_y2_output_loss: 2.4897 - val_y1_output_root_mean_squared_error: 0.7851 - val_y2_output_root_mean_squared_error: 1.5995
# Epoch 92/500
# 614/614 [==============================] - 0s 156us/sample - loss: 4.1165 - y1_output_loss: 1.1043 - y2_output_loss: 2.9967 - y1_output_root_mean_squared_error: 1.0510 - y2_output_root_mean_squared_error: 1.7355 - val_loss: 3.7530 - val_y1_output_loss: 1.4225 - val_y2_output_loss: 2.2041 - val_y1_output_root_mean_squared_error: 1.2131 - val_y2_output_root_mean_squared_error: 1.5104
# Epoch 93/500
# 614/614 [==============================] - 0s 146us/sample - loss: 4.0654 - y1_output_loss: 0.9932 - y2_output_loss: 3.0629 - y1_output_root_mean_squared_error: 0.9984 - y2_output_root_mean_squared_error: 1.7517 - val_loss: 4.2572 - val_y1_output_loss: 1.0754 - val_y2_output_loss: 3.0979 - val_y1_output_root_mean_squared_error: 1.0474 - val_y2_output_root_mean_squared_error: 1.7777
# Epoch 94/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9070 - y1_output_loss: 0.6926 - y2_output_loss: 2.2054 - y1_output_root_mean_squared_error: 0.8337 - y2_output_root_mean_squared_error: 1.4872 - val_loss: 3.0143 - val_y1_output_loss: 0.5700 - val_y2_output_loss: 2.3547 - val_y1_output_root_mean_squared_error: 0.7665 - val_y2_output_root_mean_squared_error: 1.5578
# Epoch 95/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5194 - y1_output_loss: 0.7963 - y2_output_loss: 2.7052 - y1_output_root_mean_squared_error: 0.8898 - y2_output_root_mean_squared_error: 1.6516 - val_loss: 4.8883 - val_y1_output_loss: 1.9425 - val_y2_output_loss: 2.7768 - val_y1_output_root_mean_squared_error: 1.4176 - val_y2_output_root_mean_squared_error: 1.6967
# Epoch 96/500
# 614/614 [==============================] - 0s 164us/sample - loss: 2.7503 - y1_output_loss: 0.6851 - y2_output_loss: 2.0855 - y1_output_root_mean_squared_error: 0.8303 - y2_output_root_mean_squared_error: 1.4356 - val_loss: 4.7766 - val_y1_output_loss: 0.5598 - val_y2_output_loss: 4.1226 - val_y1_output_root_mean_squared_error: 0.7604 - val_y2_output_root_mean_squared_error: 2.0490
# Epoch 97/500
# 614/614 [==============================] - 0s 143us/sample - loss: 4.3537 - y1_output_loss: 1.1230 - y2_output_loss: 3.2221 - y1_output_root_mean_squared_error: 1.0586 - y2_output_root_mean_squared_error: 1.7981 - val_loss: 6.8438 - val_y1_output_loss: 2.1354 - val_y2_output_loss: 4.5285 - val_y1_output_root_mean_squared_error: 1.4821 - val_y2_output_root_mean_squared_error: 2.1557
# Epoch 98/500
# 614/614 [==============================] - 0s 166us/sample - loss: 5.6021 - y1_output_loss: 1.5390 - y2_output_loss: 4.0121 - y1_output_root_mean_squared_error: 1.2459 - y2_output_root_mean_squared_error: 2.0124 - val_loss: 2.0428 - val_y1_output_loss: 0.5068 - val_y2_output_loss: 1.4635 - val_y1_output_root_mean_squared_error: 0.7242 - val_y2_output_root_mean_squared_error: 1.2322
# Epoch 99/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.8352 - y1_output_loss: 0.6405 - y2_output_loss: 2.1782 - y1_output_root_mean_squared_error: 0.7984 - y2_output_root_mean_squared_error: 1.4825 - val_loss: 1.9930 - val_y1_output_loss: 0.5099 - val_y2_output_loss: 1.4164 - val_y1_output_root_mean_squared_error: 0.7259 - val_y2_output_root_mean_squared_error: 1.2108
# Epoch 100/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.0245 - y1_output_loss: 0.6937 - y2_output_loss: 2.3036 - y1_output_root_mean_squared_error: 0.8364 - y2_output_root_mean_squared_error: 1.5248 - val_loss: 2.2508 - val_y1_output_loss: 0.7249 - val_y2_output_loss: 1.4478 - val_y1_output_root_mean_squared_error: 0.8657 - val_y2_output_root_mean_squared_error: 1.2253
# Epoch 101/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.1138 - y1_output_loss: 0.7361 - y2_output_loss: 2.4001 - y1_output_root_mean_squared_error: 0.8593 - y2_output_root_mean_squared_error: 1.5413 - val_loss: 4.2889 - val_y1_output_loss: 0.9408 - val_y2_output_loss: 3.2325 - val_y1_output_root_mean_squared_error: 0.9850 - val_y2_output_root_mean_squared_error: 1.8217
# Epoch 102/500
# 614/614 [==============================] - 0s 162us/sample - loss: 3.0717 - y1_output_loss: 0.6677 - y2_output_loss: 2.3962 - y1_output_root_mean_squared_error: 0.8183 - y2_output_root_mean_squared_error: 1.5498 - val_loss: 2.6484 - val_y1_output_loss: 0.6069 - val_y2_output_loss: 1.9928 - val_y1_output_root_mean_squared_error: 0.7893 - val_y2_output_root_mean_squared_error: 1.4232
# Epoch 103/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.6243 - y1_output_loss: 2.2492 - y2_output_loss: 5.3526 - y1_output_root_mean_squared_error: 1.5055 - y2_output_root_mean_squared_error: 2.3147 - val_loss: 5.7504 - val_y1_output_loss: 0.6872 - val_y2_output_loss: 4.9149 - val_y1_output_root_mean_squared_error: 0.8397 - val_y2_output_root_mean_squared_error: 2.2462
# Epoch 104/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.3997 - y1_output_loss: 0.5354 - y2_output_loss: 1.8940 - y1_output_root_mean_squared_error: 0.7323 - y2_output_root_mean_squared_error: 1.3651 - val_loss: 5.9135 - val_y1_output_loss: 0.8601 - val_y2_output_loss: 4.8808 - val_y1_output_root_mean_squared_error: 0.9439 - val_y2_output_root_mean_squared_error: 2.2411
# Epoch 105/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.4720 - y1_output_loss: 0.5211 - y2_output_loss: 1.9435 - y1_output_root_mean_squared_error: 0.7217 - y2_output_root_mean_squared_error: 1.3968 - val_loss: 2.3595 - val_y1_output_loss: 0.7208 - val_y2_output_loss: 1.5879 - val_y1_output_root_mean_squared_error: 0.8609 - val_y2_output_root_mean_squared_error: 1.2722
# Epoch 106/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.3449 - y1_output_loss: 0.4996 - y2_output_loss: 1.8485 - y1_output_root_mean_squared_error: 0.7060 - y2_output_root_mean_squared_error: 1.3588 - val_loss: 2.3171 - val_y1_output_loss: 0.5846 - val_y2_output_loss: 1.6581 - val_y1_output_root_mean_squared_error: 0.7778 - val_y2_output_root_mean_squared_error: 1.3085
# Epoch 107/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.6381 - y1_output_loss: 0.6113 - y2_output_loss: 2.0258 - y1_output_root_mean_squared_error: 0.7816 - y2_output_root_mean_squared_error: 1.4238 - val_loss: 2.1171 - val_y1_output_loss: 0.4835 - val_y2_output_loss: 1.5593 - val_y1_output_root_mean_squared_error: 0.7077 - val_y2_output_root_mean_squared_error: 1.2714
# Epoch 108/500
# 614/614 [==============================] - 0s 166us/sample - loss: 2.2994 - y1_output_loss: 0.4765 - y2_output_loss: 1.8444 - y1_output_root_mean_squared_error: 0.6912 - y2_output_root_mean_squared_error: 1.3497 - val_loss: 4.1227 - val_y1_output_loss: 0.5673 - val_y2_output_loss: 3.4262 - val_y1_output_root_mean_squared_error: 0.7643 - val_y2_output_root_mean_squared_error: 1.8811
# Epoch 109/500
# 614/614 [==============================] - 0s 147us/sample - loss: 2.6208 - y1_output_loss: 0.6716 - y2_output_loss: 1.9756 - y1_output_root_mean_squared_error: 0.8142 - y2_output_root_mean_squared_error: 1.3993 - val_loss: 7.1267 - val_y1_output_loss: 2.1273 - val_y2_output_loss: 4.8014 - val_y1_output_root_mean_squared_error: 1.4826 - val_y2_output_root_mean_squared_error: 2.2201
# Epoch 110/500
# 614/614 [==============================] - 0s 159us/sample - loss: 3.2825 - y1_output_loss: 0.7290 - y2_output_loss: 2.5372 - y1_output_root_mean_squared_error: 0.8560 - y2_output_root_mean_squared_error: 1.5968 - val_loss: 2.1019 - val_y1_output_loss: 0.4530 - val_y2_output_loss: 1.5784 - val_y1_output_root_mean_squared_error: 0.6836 - val_y2_output_root_mean_squared_error: 1.2785
# Epoch 111/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.2823 - y1_output_loss: 0.4870 - y2_output_loss: 1.7811 - y1_output_root_mean_squared_error: 0.6965 - y2_output_root_mean_squared_error: 1.3406 - val_loss: 2.1957 - val_y1_output_loss: 0.5908 - val_y2_output_loss: 1.5398 - val_y1_output_root_mean_squared_error: 0.7767 - val_y2_output_root_mean_squared_error: 1.2619
# Epoch 112/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.0741 - y1_output_loss: 0.6839 - y2_output_loss: 2.3820 - y1_output_root_mean_squared_error: 0.8305 - y2_output_root_mean_squared_error: 1.5441 - val_loss: 2.1835 - val_y1_output_loss: 0.5651 - val_y2_output_loss: 1.5429 - val_y1_output_root_mean_squared_error: 0.7635 - val_y2_output_root_mean_squared_error: 1.2652
# Epoch 113/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.0156 - y1_output_loss: 0.5834 - y2_output_loss: 2.4086 - y1_output_root_mean_squared_error: 0.7655 - y2_output_root_mean_squared_error: 1.5587 - val_loss: 3.1794 - val_y1_output_loss: 0.5758 - val_y2_output_loss: 2.4974 - val_y1_output_root_mean_squared_error: 0.7723 - val_y2_output_root_mean_squared_error: 1.6072
# Epoch 114/500
# 614/614 [==============================] - 0s 168us/sample - loss: 3.2542 - y1_output_loss: 0.7381 - y2_output_loss: 2.5224 - y1_output_root_mean_squared_error: 0.8632 - y2_output_root_mean_squared_error: 1.5840 - val_loss: 3.4208 - val_y1_output_loss: 0.4649 - val_y2_output_loss: 2.8529 - val_y1_output_root_mean_squared_error: 0.6929 - val_y2_output_root_mean_squared_error: 1.7148
# Epoch 115/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.1956 - y1_output_loss: 0.4974 - y2_output_loss: 1.7171 - y1_output_root_mean_squared_error: 0.7073 - y2_output_root_mean_squared_error: 1.3021 - val_loss: 4.3726 - val_y1_output_loss: 0.6303 - val_y2_output_loss: 3.6567 - val_y1_output_root_mean_squared_error: 0.8060 - val_y2_output_root_mean_squared_error: 1.9295
# Epoch 116/500
# 614/614 [==============================] - 0s 167us/sample - loss: 3.3939 - y1_output_loss: 0.7347 - y2_output_loss: 2.6395 - y1_output_root_mean_squared_error: 0.8604 - y2_output_root_mean_squared_error: 1.6290 - val_loss: 1.7918 - val_y1_output_loss: 0.4545 - val_y2_output_loss: 1.2865 - val_y1_output_root_mean_squared_error: 0.6845 - val_y2_output_root_mean_squared_error: 1.1504
# Epoch 117/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.4449 - y1_output_loss: 0.5151 - y2_output_loss: 1.9196 - y1_output_root_mean_squared_error: 0.7194 - y2_output_root_mean_squared_error: 1.3883 - val_loss: 2.1844 - val_y1_output_loss: 0.4827 - val_y2_output_loss: 1.6261 - val_y1_output_root_mean_squared_error: 0.7045 - val_y2_output_root_mean_squared_error: 1.2993
# Epoch 118/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.6603 - y1_output_loss: 0.6025 - y2_output_loss: 2.0639 - y1_output_root_mean_squared_error: 0.7769 - y2_output_root_mean_squared_error: 1.4341 - val_loss: 3.1620 - val_y1_output_loss: 1.2264 - val_y2_output_loss: 1.8359 - val_y1_output_root_mean_squared_error: 1.1238 - val_y2_output_root_mean_squared_error: 1.3781
# Epoch 119/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.9458 - y1_output_loss: 0.6189 - y2_output_loss: 2.3182 - y1_output_root_mean_squared_error: 0.7870 - y2_output_root_mean_squared_error: 1.5253 - val_loss: 1.9883 - val_y1_output_loss: 0.5455 - val_y2_output_loss: 1.3810 - val_y1_output_root_mean_squared_error: 0.7519 - val_y2_output_root_mean_squared_error: 1.1928
# Epoch 120/500
# 614/614 [==============================] - 0s 158us/sample - loss: 2.1476 - y1_output_loss: 0.4596 - y2_output_loss: 1.6773 - y1_output_root_mean_squared_error: 0.6771 - y2_output_root_mean_squared_error: 1.2997 - val_loss: 1.8752 - val_y1_output_loss: 0.4825 - val_y2_output_loss: 1.3407 - val_y1_output_root_mean_squared_error: 0.7073 - val_y2_output_root_mean_squared_error: 1.1725
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 154us/sample - loss: 0.5206 - y1_output_loss: 0.1640 - y2_output_loss: 0.3555 - y1_output_root_mean_squared_error: 0.4062 - y2_output_root_mean_squared_error: 0.5963 - val_loss: 1.0001 - val_y1_output_loss: 0.2475 - val_y2_output_loss: 0.7591 - val_y1_output_root_mean_squared_error: 0.4947 - val_y2_output_root_mean_squared_error: 0.8691
# Epoch 462/500
# 614/614 [==============================] - 0s 179us/sample - loss: 0.4452 - y1_output_loss: 0.1182 - y2_output_loss: 0.3299 - y1_output_root_mean_squared_error: 0.3407 - y2_output_root_mean_squared_error: 0.5737 - val_loss: 0.9287 - val_y1_output_loss: 0.2431 - val_y2_output_loss: 0.6699 - val_y1_output_root_mean_squared_error: 0.4934 - val_y2_output_root_mean_squared_error: 0.8278
# Epoch 463/500
# 614/614 [==============================] - 0s 163us/sample - loss: 0.4970 - y1_output_loss: 0.1344 - y2_output_loss: 0.3585 - y1_output_root_mean_squared_error: 0.3678 - y2_output_root_mean_squared_error: 0.6015 - val_loss: 0.7273 - val_y1_output_loss: 0.1782 - val_y2_output_loss: 0.5482 - val_y1_output_root_mean_squared_error: 0.4228 - val_y2_output_root_mean_squared_error: 0.7406
# Epoch 464/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3727 - y1_output_loss: 0.1160 - y2_output_loss: 0.2560 - y1_output_root_mean_squared_error: 0.3403 - y2_output_root_mean_squared_error: 0.5069 - val_loss: 0.7281 - val_y1_output_loss: 0.2141 - val_y2_output_loss: 0.5085 - val_y1_output_root_mean_squared_error: 0.4611 - val_y2_output_root_mean_squared_error: 0.7179
# Epoch 465/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4946 - y1_output_loss: 0.1366 - y2_output_loss: 0.3580 - y1_output_root_mean_squared_error: 0.3711 - y2_output_root_mean_squared_error: 0.5974 - val_loss: 1.2501 - val_y1_output_loss: 0.1948 - val_y2_output_loss: 1.0191 - val_y1_output_root_mean_squared_error: 0.4422 - val_y2_output_root_mean_squared_error: 1.0269
# Epoch 466/500
# 614/614 [==============================] - 0s 153us/sample - loss: 0.5206 - y1_output_loss: 0.1242 - y2_output_loss: 0.3941 - y1_output_root_mean_squared_error: 0.3530 - y2_output_root_mean_squared_error: 0.6293 - val_loss: 0.9873 - val_y1_output_loss: 0.2176 - val_y2_output_loss: 0.7440 - val_y1_output_root_mean_squared_error: 0.4679 - val_y2_output_root_mean_squared_error: 0.8765
# Epoch 467/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4207 - y1_output_loss: 0.1208 - y2_output_loss: 0.2984 - y1_output_root_mean_squared_error: 0.3485 - y2_output_root_mean_squared_error: 0.5471 - val_loss: 0.6990 - val_y1_output_loss: 0.1946 - val_y2_output_loss: 0.4983 - val_y1_output_root_mean_squared_error: 0.4421 - val_y2_output_root_mean_squared_error: 0.7097
# Epoch 468/500
# 614/614 [==============================] - 0s 167us/sample - loss: 0.3484 - y1_output_loss: 0.1095 - y2_output_loss: 0.2461 - y1_output_root_mean_squared_error: 0.3313 - y2_output_root_mean_squared_error: 0.4885 - val_loss: 2.2912 - val_y1_output_loss: 0.3333 - val_y2_output_loss: 1.8950 - val_y1_output_root_mean_squared_error: 0.5797 - val_y2_output_root_mean_squared_error: 1.3983
# Epoch 469/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.4788 - y1_output_loss: 0.1169 - y2_output_loss: 0.3699 - y1_output_root_mean_squared_error: 0.3424 - y2_output_root_mean_squared_error: 0.6013 - val_loss: 1.4445 - val_y1_output_loss: 0.2204 - val_y2_output_loss: 1.1871 - val_y1_output_root_mean_squared_error: 0.4684 - val_y2_output_root_mean_squared_error: 1.1069
# Epoch 470/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.5972 - y1_output_loss: 0.1559 - y2_output_loss: 0.4430 - y1_output_root_mean_squared_error: 0.3919 - y2_output_root_mean_squared_error: 0.6660 - val_loss: 0.9364 - val_y1_output_loss: 0.2845 - val_y2_output_loss: 0.6338 - val_y1_output_root_mean_squared_error: 0.5380 - val_y2_output_root_mean_squared_error: 0.8043
# Epoch 471/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.4194 - y1_output_loss: 0.1231 - y2_output_loss: 0.2989 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5450 - val_loss: 0.7087 - val_y1_output_loss: 0.1836 - val_y2_output_loss: 0.5256 - val_y1_output_root_mean_squared_error: 0.4314 - val_y2_output_root_mean_squared_error: 0.7229
# Epoch 472/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.9103 - y1_output_loss: 0.2441 - y2_output_loss: 0.6654 - y1_output_root_mean_squared_error: 0.4959 - y2_output_root_mean_squared_error: 0.8151 - val_loss: 1.3134 - val_y1_output_loss: 0.2511 - val_y2_output_loss: 1.1054 - val_y1_output_root_mean_squared_error: 0.5088 - val_y2_output_root_mean_squared_error: 1.0269
# Epoch 473/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3771 - y1_output_loss: 0.1073 - y2_output_loss: 0.2733 - y1_output_root_mean_squared_error: 0.3273 - y2_output_root_mean_squared_error: 0.5196 - val_loss: 1.8670 - val_y1_output_loss: 0.1875 - val_y2_output_loss: 1.6258 - val_y1_output_root_mean_squared_error: 0.4339 - val_y2_output_root_mean_squared_error: 1.2957
# Epoch 474/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.3799 - y1_output_loss: 0.1107 - y2_output_loss: 0.2703 - y1_output_root_mean_squared_error: 0.3316 - y2_output_root_mean_squared_error: 0.5195 - val_loss: 1.3291 - val_y1_output_loss: 0.5494 - val_y2_output_loss: 0.7491 - val_y1_output_root_mean_squared_error: 0.7532 - val_y2_output_root_mean_squared_error: 0.8728
# Epoch 475/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.7090 - y1_output_loss: 0.2182 - y2_output_loss: 0.4907 - y1_output_root_mean_squared_error: 0.4659 - y2_output_root_mean_squared_error: 0.7014 - val_loss: 1.0600 - val_y1_output_loss: 0.3908 - val_y2_output_loss: 0.6524 - val_y1_output_root_mean_squared_error: 0.6343 - val_y2_output_root_mean_squared_error: 0.8109
# Epoch 476/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3378 - y1_output_loss: 0.1138 - y2_output_loss: 0.2228 - y1_output_root_mean_squared_error: 0.3388 - y2_output_root_mean_squared_error: 0.4723 - val_loss: 0.7839 - val_y1_output_loss: 0.1891 - val_y2_output_loss: 0.5895 - val_y1_output_root_mean_squared_error: 0.4327 - val_y2_output_root_mean_squared_error: 0.7725
# Epoch 477/500
# 614/614 [==============================] - 0s 162us/sample - loss: 0.4124 - y1_output_loss: 0.1124 - y2_output_loss: 0.2978 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.5480 - val_loss: 0.6278 - val_y1_output_loss: 0.1809 - val_y2_output_loss: 0.4466 - val_y1_output_root_mean_squared_error: 0.4250 - val_y2_output_root_mean_squared_error: 0.6687
# Epoch 478/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.3592 - y1_output_loss: 0.1202 - y2_output_loss: 0.2356 - y1_output_root_mean_squared_error: 0.3483 - y2_output_root_mean_squared_error: 0.4877 - val_loss: 0.6653 - val_y1_output_loss: 0.1866 - val_y2_output_loss: 0.4707 - val_y1_output_root_mean_squared_error: 0.4335 - val_y2_output_root_mean_squared_error: 0.6909
# Epoch 479/500
# 614/614 [==============================] - 0s 155us/sample - loss: 0.3371 - y1_output_loss: 0.1043 - y2_output_loss: 0.2329 - y1_output_root_mean_squared_error: 0.3226 - y2_output_root_mean_squared_error: 0.4827 - val_loss: 0.8747 - val_y1_output_loss: 0.1822 - val_y2_output_loss: 0.7040 - val_y1_output_root_mean_squared_error: 0.4294 - val_y2_output_root_mean_squared_error: 0.8309
# Epoch 480/500
# 614/614 [==============================] - 0s 191us/sample - loss: 0.4173 - y1_output_loss: 0.1264 - y2_output_loss: 0.2901 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5387 - val_loss: 1.0790 - val_y1_output_loss: 0.1944 - val_y2_output_loss: 0.8649 - val_y1_output_root_mean_squared_error: 0.4397 - val_y2_output_root_mean_squared_error: 0.9411
# Epoch 481/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.3600 - y1_output_loss: 0.1149 - y2_output_loss: 0.2446 - y1_output_root_mean_squared_error: 0.3382 - y2_output_root_mean_squared_error: 0.4956 - val_loss: 1.1996 - val_y1_output_loss: 0.1697 - val_y2_output_loss: 0.9953 - val_y1_output_root_mean_squared_error: 0.4116 - val_y2_output_root_mean_squared_error: 1.0150
# Epoch 482/500
# 614/614 [==============================] - 0s 146us/sample - loss: 0.3164 - y1_output_loss: 0.1034 - y2_output_loss: 0.2143 - y1_output_root_mean_squared_error: 0.3218 - y2_output_root_mean_squared_error: 0.4613 - val_loss: 0.9534 - val_y1_output_loss: 0.3859 - val_y2_output_loss: 0.5466 - val_y1_output_root_mean_squared_error: 0.6296 - val_y2_output_root_mean_squared_error: 0.7463
# Epoch 483/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.3317 - y1_output_loss: 0.1071 - y2_output_loss: 0.2220 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4730 - val_loss: 0.7566 - val_y1_output_loss: 0.1776 - val_y2_output_loss: 0.5663 - val_y1_output_root_mean_squared_error: 0.4176 - val_y2_output_root_mean_squared_error: 0.7630
# Epoch 484/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4048 - y1_output_loss: 0.1209 - y2_output_loss: 0.2850 - y1_output_root_mean_squared_error: 0.3469 - y2_output_root_mean_squared_error: 0.5333 - val_loss: 2.1124 - val_y1_output_loss: 0.7579 - val_y2_output_loss: 1.3051 - val_y1_output_root_mean_squared_error: 0.8869 - val_y2_output_root_mean_squared_error: 1.1515
# Epoch 485/500
# 614/614 [==============================] - 0s 176us/sample - loss: 1.3996 - y1_output_loss: 0.3185 - y2_output_loss: 1.0710 - y1_output_root_mean_squared_error: 0.5666 - y2_output_root_mean_squared_error: 1.0385 - val_loss: 0.7941 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.5814 - val_y1_output_root_mean_squared_error: 0.4420 - val_y2_output_root_mean_squared_error: 0.7738
# Epoch 486/500
# 614/614 [==============================] - 0s 172us/sample - loss: 0.3699 - y1_output_loss: 0.1016 - y2_output_loss: 0.2658 - y1_output_root_mean_squared_error: 0.3198 - y2_output_root_mean_squared_error: 0.5173 - val_loss: 0.8153 - val_y1_output_loss: 0.2093 - val_y2_output_loss: 0.5881 - val_y1_output_root_mean_squared_error: 0.4565 - val_y2_output_root_mean_squared_error: 0.7791
# Epoch 487/500
# 614/614 [==============================] - 0s 158us/sample - loss: 0.3975 - y1_output_loss: 0.1036 - y2_output_loss: 0.2957 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.5415 - val_loss: 0.9686 - val_y1_output_loss: 0.2105 - val_y2_output_loss: 0.7443 - val_y1_output_root_mean_squared_error: 0.4585 - val_y2_output_root_mean_squared_error: 0.8708
# Epoch 488/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3548 - y1_output_loss: 0.1154 - y2_output_loss: 0.2423 - y1_output_root_mean_squared_error: 0.3368 - y2_output_root_mean_squared_error: 0.4913 - val_loss: 1.1822 - val_y1_output_loss: 0.4060 - val_y2_output_loss: 0.7500 - val_y1_output_root_mean_squared_error: 0.6452 - val_y2_output_root_mean_squared_error: 0.8752
# Epoch 489/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.3414 - y1_output_loss: 0.1174 - y2_output_loss: 0.2242 - y1_output_root_mean_squared_error: 0.3408 - y2_output_root_mean_squared_error: 0.4746 - val_loss: 0.6069 - val_y1_output_loss: 0.1595 - val_y2_output_loss: 0.4405 - val_y1_output_root_mean_squared_error: 0.4005 - val_y2_output_root_mean_squared_error: 0.6682
# Epoch 490/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.3259 - y1_output_loss: 0.1059 - y2_output_loss: 0.2178 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.4688 - val_loss: 0.6165 - val_y1_output_loss: 0.1826 - val_y2_output_loss: 0.4312 - val_y1_output_root_mean_squared_error: 0.4288 - val_y2_output_root_mean_squared_error: 0.6577
# Epoch 491/500
# 614/614 [==============================] - 0s 197us/sample - loss: 0.4943 - y1_output_loss: 0.1211 - y2_output_loss: 0.3770 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.6116 - val_loss: 0.7247 - val_y1_output_loss: 0.2020 - val_y2_output_loss: 0.5322 - val_y1_output_root_mean_squared_error: 0.4550 - val_y2_output_root_mean_squared_error: 0.7195
# Epoch 492/500
# 614/614 [==============================] - 0s 159us/sample - loss: 0.4072 - y1_output_loss: 0.1289 - y2_output_loss: 0.2840 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5314 - val_loss: 0.6381 - val_y1_output_loss: 0.1819 - val_y2_output_loss: 0.4518 - val_y1_output_root_mean_squared_error: 0.4288 - val_y2_output_root_mean_squared_error: 0.6740
# Epoch 493/500
# 614/614 [==============================] - 0s 147us/sample - loss: 0.4769 - y1_output_loss: 0.1295 - y2_output_loss: 0.3477 - y1_output_root_mean_squared_error: 0.3605 - y2_output_root_mean_squared_error: 0.5890 - val_loss: 0.9066 - val_y1_output_loss: 0.1945 - val_y2_output_loss: 0.7092 - val_y1_output_root_mean_squared_error: 0.4440 - val_y2_output_root_mean_squared_error: 0.8423
# Epoch 494/500
# 614/614 [==============================] - 0s 156us/sample - loss: 0.6950 - y1_output_loss: 0.1629 - y2_output_loss: 0.5265 - y1_output_root_mean_squared_error: 0.4044 - y2_output_root_mean_squared_error: 0.7290 - val_loss: 0.6429 - val_y1_output_loss: 0.1722 - val_y2_output_loss: 0.4674 - val_y1_output_root_mean_squared_error: 0.4126 - val_y2_output_root_mean_squared_error: 0.6875
# Epoch 495/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.4173 - y1_output_loss: 0.1163 - y2_output_loss: 0.2991 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5481 - val_loss: 0.8202 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.6059 - val_y1_output_root_mean_squared_error: 0.4659 - val_y2_output_root_mean_squared_error: 0.7766
# Epoch 496/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3553 - y1_output_loss: 0.1075 - y2_output_loss: 0.2453 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4972 - val_loss: 0.6503 - val_y1_output_loss: 0.1794 - val_y2_output_loss: 0.4699 - val_y1_output_root_mean_squared_error: 0.4218 - val_y2_output_root_mean_squared_error: 0.6873
# Epoch 497/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.3694 - y1_output_loss: 0.1161 - y2_output_loss: 0.2502 - y1_output_root_mean_squared_error: 0.3421 - y2_output_root_mean_squared_error: 0.5023 - val_loss: 0.6429 - val_y1_output_loss: 0.1831 - val_y2_output_loss: 0.4551 - val_y1_output_root_mean_squared_error: 0.4235 - val_y2_output_root_mean_squared_error: 0.6808
# Epoch 498/500
# 614/614 [==============================] - 0s 157us/sample - loss: 0.4121 - y1_output_loss: 0.1042 - y2_output_loss: 0.3048 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.5540 - val_loss: 0.6703 - val_y1_output_loss: 0.1972 - val_y2_output_loss: 0.4808 - val_y1_output_root_mean_squared_error: 0.4490 - val_y2_output_root_mean_squared_error: 0.6846
# Epoch 499/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4447 - y1_output_loss: 0.1331 - y2_output_loss: 0.3377 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5606 - val_loss: 2.5725 - val_y1_output_loss: 0.5816 - val_y2_output_loss: 1.9222 - val_y1_output_root_mean_squared_error: 0.7682 - val_y2_output_root_mean_squared_error: 1.4080
# Epoch 500/500
# 614/614 [==============================] - 0s 161us/sample - loss: 0.6188 - y1_output_loss: 0.1859 - y2_output_loss: 0.4275 - y1_output_root_mean_squared_error: 0.4328 - y2_output_root_mean_squared_error: 0.6569 - val_loss: 0.7513 - val_y1_output_loss: 0.1810 - val_y2_output_loss: 0.5534 - val_y1_output_root_mean_squared_error: 0.4252 - val_y2_output_root_mean_squared_error: 0.7553

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 46us/sample - loss: 0.7513 - y1_output_loss: 0.1877 - y2_output_loss: 0.5872 - y1_output_root_mean_squared_error: 0.4252 - y2_output_root_mean_squared_error: 0.7553
# Loss = 0.7513118734607449, Y1_loss = 0.18765994906425476, Y1_mse = 0.4252031147480011, Y2_loss = 0.5871802568435669, Y2_mse = 0.7553238868713379

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
